# %%
from cropgen.shared.PathBundle import PathBundle
from cropgen.external_interfaces.LabelStudioInterface import LabelStudioInterface
from cropgen.external_interfaces.OracleBucketInterface import OracleBucketInterface
from dotenv import load_dotenv
from cropgen.processing.parallel.augment_data_parallel import augment_data_parallel

load_dotenv()
paths = PathBundle(r"C:\Users\pambi\Documents\1Universidad\TFG\CropgeneratorOOP")

# %%
OracleBucketInterface(paths).update()
LabelStudioInterface.update_conditional(paths)
lsi = LabelStudioInterface(paths)


augment_data_parallel(paths, [1], True, True, lsi=lsi, tasks_only= None)
# Out:
# Export local ya actualizado. No se descarga nada.
# Procesando 605 tareas usando 6 núcleos.
# Exception in thread Thread-4 (_handle_results):
# Traceback (most recent call last):
#   File "C:\Users\pambi\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\pambi\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pambi\anaconda3\Lib\multiprocessing\pool.py", line 579, in _handle_results
#     task = get()
#   File "C:\Users\pambi\anaconda3\Lib\multiprocessing\connection.py", line 251, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\pambi\Documents\1Universidad\TFG\CropgeneratorOOP\cropgen\processing\helpers\PairingErrors.py", line 56, in __init__
#     raise ValueError(
#         f"No se ha detectado que sea ni un ImageBox ni un TextFragment, el tipo {object_type} no se acepta."
#     )
# ValueError: No se ha detectado que sea ni un ImageBox ni un TextFragment, el tipo str no se acepta.

# %%
from cropgen.splitter.dataset_interface.DatasetInterface import DatasetInterface

dsi = DatasetInterface(paths)
# TODO: recuerda que los fragmentos que se eliminan del grafo tienen starting_index = -1
dsi.split(0.9, (1,))

#TODO: continue implementing the dataset generation here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from cropgen.splitter.dataset_interface.DatasetInterface import DatasetInterface
# ----> 3 dsi = DatasetInterface(paths)
#       5 dsi.split(0.9, (1,))
#       7 #TODO: continue implementing the dataset generation here
#
# File ~\Documents\1Universidad\TFG\CropgeneratorOOP\cropgen\splitter\dataset_interface\DatasetInterface.py:19, in DatasetInterface.__init__(self, paths)
#      14 if "is_letter" not in self.df.columns:
#      15     self.df["is_letter"] = self.df.page.apply(
#      16         lambda x: isinstance(x, int) or str(x).isdigit()
#      17     )
# ---> 19 self.df["has_enough_context"] = ~self.df.apply(
#      20     lambda x: (x.sindex <= max_context_chars) and (prev_page(x.page) == False),
#      21     axis=1,
#      22 )
#      24 df_len1 = self.df[self.df.order == 1]
#      25 df_full = self.df[self.df.order == "full"]
#
# File ~\Documents\1Universidad\TFG\CropgeneratorOOP\.venv\Lib\site-packages\pandas\core\frame.py:12419, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12405         raise ValueError(f"Unknown engine '{engine}'")
#   12407     op = frame_apply(
#   12408         self,
#   12409         func=func,
#    (...)  12417         kwargs=kwargs,
#   12418     )
# > 12419     return op.apply().__finalize__(self, method="apply")
#   12420 elif hasattr(engine, "__pandas_udf__"):
#   12421     if result_type is not None:
#
# File ~\Documents\1Universidad\TFG\CropgeneratorOOP\.venv\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File ~\Documents\1Universidad\TFG\CropgeneratorOOP\.venv\Lib\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File ~\Documents\1Universidad\TFG\CropgeneratorOOP\.venv\Lib\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# File ~\Documents\1Universidad\TFG\CropgeneratorOOP\cropgen\splitter\dataset_interface\DatasetInterface.py:20, in DatasetInterface.__init__.<locals>.<lambda>(x)
#      14 if "is_letter" not in self.df.columns:
#      15     self.df["is_letter"] = self.df.page.apply(
#      16         lambda x: isinstance(x, int) or str(x).isdigit()
#      17     )
#      19 self.df["has_enough_context"] = ~self.df.apply(
# ---> 20     lambda x: (x.sindex <= max_context_chars) and (prev_page(x.page) == False),
#      21     axis=1,
#      22 )
#      24 df_len1 = self.df[self.df.order == 1]
#      25 df_full = self.df[self.df.order == "full"]
#
# TypeError: prev_page() missing 1 required positional argument: 'pages'
